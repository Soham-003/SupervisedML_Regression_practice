# %%
import pandas as pd
df = pd.read_csv("C:/Users/Rager/Downloads/titanic_mod.csv")
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500

# %%
df.describe()
# Out:
#        passenger_id     survived       pclass       gender          age  \
# count   1046.000000  1046.000000  1046.000000  1046.000000  1046.000000
# mean     523.500000     0.408222     2.207457     0.629063    29.879541
# std      302.098494     0.491740     0.841497     0.483287    14.407561
# min        1.000000     0.000000     1.000000     0.000000     1.000000
# 25%      262.250000     0.000000     1.000000     0.000000    21.000000
# 50%      523.500000     0.000000     2.000000     1.000000    28.000000
# 75%      784.750000     1.000000     3.000000     1.000000    39.000000
# max     1046.000000     1.000000     3.000000     1.000000    80.000000
#
#              sibsp       parch         fare
# count  1046.000000  1046.00000  1046.000000
# mean      0.502868     0.42065    36.651199
# std       0.912167     0.83975    55.717501
# min       0.000000     0.00000     0.000000
# 25%       0.000000     0.00000     8.050000
# 50%       0.000000     0.00000    15.750000
# 75%       1.000000     1.00000    35.500000
# max       8.000000     6.00000   512.329200

# %%
df.dtypes[df.dtypes == 'int64'].index
# Out:
# Index(['passenger_id', 'survived', 'pclass', 'gender', 'age', 'sibsp',
#        'parch'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['passenger_id', 'survived', 'pclass', 'gender', 'age', 'sibsp', 'parch',
#        'fare'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#       passenger_id  survived  pclass  gender  age  sibsp  parch
# 0                1         1       1       0   29      0      0
# 1                2         1       1       1    1      1      2
# 2                3         0       1       0    2      1      2
# 3                4         0       1       1   30      1      2
# 4                5         0       1       0   25      1      2
# ...            ...       ...     ...     ...  ...    ...    ...
# 1041          1042         0       3       1   46      0      0
# 1042          1043         0       3       0   15      1      0
# 1043          1044         0       3       1   27      0      0
# 1044          1045         0       3       1   27      0      0
# 1045          1046         0       3       1   29      0      0
#
# [1046 rows x 7 columns]

# %%
df[['age']][4:11]
# Out:
#     age
# 4    25
# 5    48
# 6    63
# 7    39
# 8    53
# 9    71
# 10   47

# %%
df['activity'] = df['pclass'] + df['age']

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare  \
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500
#
#    activity
# 0        30
# 1         2
# 2         3
# 3        31
# 4        26

# %%
pd.Categorical(df['sibsp'])
# Out:
# [0, 1, 1, 1, 1, ..., 0, 1, 0, 0, 0]
# Length: 1046
# Categories (7, int64): [0, 1, 2, 3, 4, 5, 8]

# %%
df['sibsp'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 8], dtype=int64)

# %%
df[(df['age'] > 25) & (df['fare'] > 150)]
# Out:
#      passenger_id  survived  pclass  gender  age  sibsp  parch      fare  \
# 0               1         1       1       0   29      0      0  211.3375
# 3               4         0       1       1   30      1      2  151.5500
# 10             11         0       1       1   47      1      0  227.5250
# 16             17         1       1       0   50      0      1  247.5208
# 22             23         1       1       0   42      0      0  227.5250
# 23             24         1       1       0   29      0      0  221.7792
# 31             32         1       1       0   30      0      0  164.8667
# 34             35         1       1       0   45      0      0  262.3750
# 45             46         1       1       1   36      0      1  512.3292
# 46             47         1       1       0   58      0      1  512.3292
# 61             62         1       1       0   36      0      0  262.3750
# 79             80         1       1       0   33      0      0  151.5500
# 88             89         1       1       0   27      1      1  247.5208
# 94             95         1       1       0   38      0      0  227.5250
# 100           101         1       1       0   28      3      2  263.0000
# 103           104         0       1       1   64      1      4  263.0000
# 104           105         1       1       0   60      1      4  263.0000
# 114           115         1       1       0   35      0      0  211.5000
# 122           123         0       1       1   38      0      1  153.4625
# 123           124         1       1       0   58      0      1  153.4625
# 153           154         0       1       1   33      0      0  211.5000
# 158           159         1       1       0   39      0      0  211.3375
# 161           162         1       1       1   35      0      0  512.3292
# 209           210         1       1       0   43      0      1  211.3375
# 222           223         0       1       1   61      1      3  262.3750
# 223           224         1       1       0   48      1      3  262.3750
# 228           229         1       1       0   40      0      0  153.4625
# 250           251         0       1       1   67      1      0  221.7792
# 251           252         0       1       0   63      1      0  221.7792
# 265           266         1       1       0   35      0      0  512.3292
# 272           273         1       1       0   31      0      2  164.8667
# 273           274         0       1       1   57      1      1  164.8667
# 274           275         1       1       0   45      1      1  164.8667
# 275           276         0       1       1   50      1      1  211.5000
# 276           277         0       1       1   27      0      2  211.5000
# 277           278         1       1       0   50      1      1  211.5000
#
#      activity
# 0          30
# 3          31
# 10         48
# 16         51
# 22         43
# 23         30
# 31         31
# 34         46
# 45         37
# 46         59
# 61         37
# 79         34
# 88         28
# 94         39
# 100        29
# 103        65
# 104        61
# 114        36
# 122        39
# 123        59
# 153        34
# 158        40
# 161        36
# 209        44
# 222        62
# 223        49
# 228        41
# 250        68
# 251        64
# 265        36
# 272        32
# 273        58
# 274        46
# 275        51
# 276        28
# 277        51

# %%
df[df['fare'] == max(df['fare'])]['age']
# Out:
# 45     36
# 46     58
# 161    35
# 265    35
# Name: age, dtype: int64

# %%
df.iloc[0:5,2:4]
# Out:
#    pclass  gender
# 0       1       0
# 1       1       1
# 2       1       0
# 3       1       1
# 4       1       0

# %%
s = df['age'][0:3]
l = ['a','b','c']
s1 = pd.Series(list(s),index = l)

# %%
s1
# Out:
# a    29
# b     1
# c     2
# dtype: int64

# %%
s1['a']
# Out:
# 29

# %%
s2 = df['activity'][0:3]
l = ['a','b','c']
s3 = pd.Series(list(s2),index = l)

# %%
s3
# Out:
# a    30
# b     2
# c     3
# dtype: int64

# %%
s1*s3
# Out:
# a    870
# b      2
# c      6
# dtype: int64

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare  \
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500
#
#    activity
# 0        30
# 1         2
# 2         3
# 3        31
# 4        26

# %%
df = df.drop("activity",axis = 1)

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500

# %%
df.set_index('passenger_id',inplace  = True)
df.head()
# Out:
#               survived  pclass  gender  age  sibsp  parch      fare
# passenger_id
# 1                    1       1       0   29      0      0  211.3375
# 2                    1       1       1    1      1      2  151.5500
# 3                    0       1       0    2      1      2  151.5500
# 4                    0       1       1   30      1      2  151.5500
# 5                    0       1       0   25      1      2  151.5500

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500

# %%
g = df.groupby("age")

# %%
g.sum()
# Out:
#      passenger_id  survived  pclass  gender  sibsp  parch      fare
# age
# 1           13828        17      57      13     26     32  625.1875
# 2            8530         4      31       5     23     15  418.5750
# 3            4497         5      18       4     12      9  170.6667
# 4            6811         7      26       5     16     14  295.4333
# 5            3046         4      14       1     11      7  122.2583
# ..            ...       ...     ...     ...    ...    ...       ...
# 70            531         0       3       2      1      1   81.5000
# 71            797         0       5       3      0      0   91.9084
# 74            995         0       3       1      0      0    7.7750
# 76             57         1       1       0      1      0   78.8500
# 80             15         1       1       1      0      0   30.0000
#
# [72 rows x 7 columns]

# %%
d = {
    'key1' : [1,2,2,1],
    'key2' : [2,3,4,5],
    'key3' : [3,4,5,6]
}
df_ = pd.DataFrame(d)
df_
# Out:
#    key1  key2  key3
# 0     1     2     3
# 1     2     3     4
# 2     2     4     5
# 3     1     5     6

# %%
g = df_.groupby("key1")
g.sum()
# Out:
#       key2  key3
# key1
# 1        7     9
# 2        7     9

# %%
g.mean()['key3']
# Out:
# key1
# 1    4.5
# 2    4.5
# Name: key3, dtype: float64

# %%
df_.head().transpose()
# Out:
#       0  1  2  3
# key1  1  2  2  1
# key2  2  3  4  5
# key3  3  4  5  6

# %%
df_['key1'][0] = 'NaN'
# Out:
# C:\Users\Rager\AppData\Local\Temp\ipykernel_1952\4107313259.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_['key1'][0] = 'NaN'

# %%
df_.head()
# Out:
#   key1  key2  key3
# 0  NaN     2     3
# 1    2     3     4
# 2    2     4     5
# 3    1     5     6

# %%
df_.fillna(1)
# Out:
#   key1  key2  key3
# 0  NaN     2     3
# 1    2     3     4
# 2    2     4     5
# 3    1     5     6

# %%
data1 = {
    'a' : [1,2,3,4],
    'b' : [2,3,4,5]
}
data2 = {
    'a' : [1,6,8,4],
    'c' : [4,3,0,9]
}
df2 = pd.DataFrame(data1)
df3 = pd.DataFrame(data2)
pd.merge(df2,df3)
# Out:
#    a  b  c
# 0  1  2  4
# 1  4  5  9

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500

# %%
df['Fare_INR'] = df['fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#    passenger_id  survived  pclass  gender  age  sibsp  parch      fare  \
# 0             1         1       1       0   29      0      0  211.3375
# 1             2         1       1       1    1      1      2  151.5500
# 2             3         0       1       0    2      1      2  151.5500
# 3             4         0       1       1   30      1      2  151.5500
# 4             5         0       1       0   25      1      2  151.5500
#
#    Fare_INR
# 0   16907.0
# 1   12124.0
# 2   12124.0
# 3   12124.0
# 4   12124.0

# %%
def test(x):
    return x.max()
df.apply(test)
# Out:
# passenger_id     1046.0000
# survived            1.0000
# pclass              3.0000
# gender              1.0000
# age                80.0000
# sibsp               8.0000
# parch               6.0000
# fare              512.3292
# Fare_INR        40986.3360
# dtype: float64

# %%
df.sort_values('age')
# Out:
#      passenger_id  survived  pclass  gender  age  sibsp  parch     fare  \
# 556           557         1       3       1    1      0      1   9.3500
# 496           497         1       2       1    1      1      1  18.7500
# 300           301         1       2       1    1      2      1  39.0000
# 999          1000         1       3       1    1      0      1   8.5167
# 961           962         1       3       0    1      1      1  16.7000
# ..            ...       ...     ...     ...  ...    ...    ...      ...
# 666           667         0       3       1   71      0      0   7.7500
# 9              10         0       1       1   71      0      0  49.5042
# 994           995         0       3       1   74      0      0   7.7750
# 56             57         1       1       0   76      1      0  78.8500
# 14             15         1       1       1   80      0      0  30.0000
#
#      Fare_INR
# 556   748.000
# 496  1500.000
# 300  3120.000
# 999   681.336
# 961  1336.000
# ..        ...
# 666   620.000
# 9    3960.336
# 994   622.000
# 56   6308.000
# 14   2400.000
#
# [1046 rows x 9 columns]

# %%
df.sort_index(ascending=False)
# Out:
#       passenger_id  survived  pclass  gender  age  sibsp  parch      fare  \
# 1045          1046         0       3       1   29      0      0    7.8750
# 1044          1045         0       3       1   27      0      0    7.2250
# 1043          1044         0       3       1   27      0      0    7.2250
# 1042          1043         0       3       0   15      1      0   14.4542
# 1041          1042         0       3       1   46      0      0    7.2250
# ...            ...       ...     ...     ...  ...    ...    ...       ...
# 4                5         0       1       0   25      1      2  151.5500
# 3                4         0       1       1   30      1      2  151.5500
# 2                3         0       1       0    2      1      2  151.5500
# 1                2         1       1       1    1      1      2  151.5500
# 0                1         1       1       0   29      0      0  211.3375
#
#        Fare_INR
# 1045    630.000
# 1044    578.000
# 1043    578.000
# 1042   1156.336
# 1041    578.000
# ...         ...
# 4     12124.000
# 3     12124.000
# 2     12124.000
# 1     12124.000
# 0     16907.000
#
# [1046 rows x 9 columns]

# %%
dfo = pd.DataFrame({'description' : ["hjhdgcjbschbsbc smbhcbsbbcjbsjbckjbjb  jksnb sm m,njkcnsnd mcnjksbnkc cmdjcbs c msnckjnsd cmnsdjkncd c dnfjknkjsnnknfkjsdncnjdhfhrd jkdnvjbhuihcnsndkaja;ekdoiesjfj  roifjejifjesjofjesjlifhjsejfnskifhisnfkrhdufhnfseijfjscfojvkldfhejcfnvuiriojfjdoifjrlivjirvjjvosk dihjfjsvjioijojo9ijvfojvoijvoljuvuovfjrlhjo"]})
pd.set_option("display.max_colwidth",1000)
dfo
# Out:
#                                                                                                                                                                                                                                                                                                           description
# 0  hjhdgcjbschbsbc smbhcbsbbcjbsjbckjbjb  jksnb sm m,njkcnsnd mcnjksbnkc cmdjcbs c msnckjnsd cmnsdjkncd c dnfjknkjsnnknfkjsdncnjdhfhrd jkdnvjbhuihcnsndkaja;ekdoiesjfj  roifjejifjesjofjesjlifhjsejfnskifhisnfkrhdufhnfseijfjscfojvkldfhejcfnvuiriojfjdoifjrlivjirvjjvosk dihjfjsvjioijojo9ijvfojvoijvoljuvuovfjrlhjo

# %%
df['age'].median()
# Out:
# 28.0

# %%
date = pd.date_range(start = '2023-04-23', end = '2023-06-23')
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
#                '2023-06-14', '2023-06-15', '2023-06-16', '2023-06-17',
#                '2023-06-18', '2023-06-19', '2023-06-20', '2023-06-21',
#                '2023-06-22', '2023-06-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date = pd.DataFrame({'date':date})
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df_date['datetime'] = pd.to_datetime(df_date['date'])
df_date
# Out:
#          date   datetime
# 0  2023-04-23 2023-04-23
# 1  2023-04-24 2023-04-24
# 2  2023-04-25 2023-04-25
# 3  2023-04-26 2023-04-26
# 4  2023-04-27 2023-04-27
# ..        ...        ...
# 57 2023-06-19 2023-06-19
# 58 2023-06-20 2023-06-20
# 59 2023-06-21 2023-06-21
# 60 2023-06-22 2023-06-22
# 61 2023-06-23 2023-06-23
#
# [62 rows x 2 columns]

# %%
df_date[df_date['date'] == object]
# Out:
#                 date   datetime  year
# 0   <class 'object'> 2023-04-23  2023
# 1   <class 'object'> 2023-04-24  2023
# 2   <class 'object'> 2023-04-25  2023
# 3   <class 'object'> 2023-04-26  2023
# 4   <class 'object'> 2023-04-27  2023
# ..               ...        ...   ...
# 57  <class 'object'> 2023-06-19  2023
# 58  <class 'object'> 2023-06-20  2023
# 59  <class 'object'> 2023-06-21  2023
# 60  <class 'object'> 2023-06-22  2023
# 61  <class 'object'> 2023-06-23  2023
#
# [62 rows x 3 columns]

# %%
df_date.dtypes
# Out:
# date                object
# datetime    datetime64[ns]
# year                 int32
# dtype: object

# %%
df_date['year'] = df_date['datetime'].dt.year

# %%
df_date.head()
# Out:
#                date   datetime  year
# 0  <class 'object'> 2023-04-23  2023
# 1  <class 'object'> 2023-04-24  2023
# 2  <class 'object'> 2023-04-25  2023
# 3  <class 'object'> 2023-04-26  2023
# 4  <class 'object'> 2023-04-27  2023

# %%
dt = pd.to_datetime('2023-06-20')
td = pd.Timedelta(days = 1)
dt + td
# Out:
# Timestamp('2023-06-21 00:00:00')

# %%
data = ['nu','fu','lu']
cat = pd.Categorical(data)
cat.value_counts()
# Out:
# fu    1
# lu    1
# nu    1
# Name: count, dtype: int64

# %%
d = pd.Series([2,4,6,8,10])
d.plot(xlabel='indices',ylabel='data')
# Out:
# <Axes: xlabel='indices', ylabel='data'>
